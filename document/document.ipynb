# %% [markdown]
# ### Data Ingestion

# %%
from langchain_core.documents import Document;

# %%
doc = Document(
    page_content="This is main content for RAG",
    metadata={
        "Source":"example.txt",
        "Author":"Zubair",
        "pages":1,
        "date":"21-12-2025"

    }
)
doc
# Out:
# Document(metadata={'Source': 'example.txt', 'Author': 'Zubair', 'pages': 1, 'date': '21-12-2025'}, page_content='This is main content for RAG')

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader(
    r"D:\New folder (2)\DS\RAG\ZuGraFix\data\text_files\aboutme.pdf"
)
documents = loader.load()

print(len(documents))
# Out:
# 2

# %%
type(documents)
# Out:
# list
